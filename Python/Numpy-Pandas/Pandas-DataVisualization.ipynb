# %%
import numpy as np
import pandas as pd

# %%
# Read the Insurance dataset with header information
infile = "C:/Users/Aniket-Admin/Desktop/ins.csv"
ins_df = pd.read_csv(infile)
ins_df.head()
# Out:
#    InsuranceId  age     sex     bmi  children smoker     region      charges
# 0      1219869   19  female  27.900       0.0    yes  southwest  16884.92400
# 1       842301   18    male  33.770       1.0     no  southeast   1725.55230
# 2      1391175   28    male  33.000       3.0    NaN  southeast   4449.46200
# 3        54198   33    male  22.705       0.0     no  northwest  21984.47061
# 4      1427400   32    male  28.880       0.0     no  northwest   3866.85520

# %%
ins_df.plot()

# %%
ins_df.children.plot.bar()

# %%
ins_df.children.value_counts().plot.bar()

# %%
ins_df.groupby(['children'])['sex'].value_counts().unstack().plot.bar(stacked = True)

# %%
ax = ins_df.groupby(['children'])['sex'].value_counts().unstack().plot.bar(stacked = True,width=0.2)

# %%
ins_aggr = pd.DataFrame(ins_df.groupby("region").charges.sum())

ins_aggr.charges.plot.bar(x = 'region')

# %%
import matplotlib.pyplot as plt

# %%
ins_df.plot.scatter(x = "charges", y = "bmi")
plt.show()

# %%
ins_df.charges.plot.hist()

# %%
# Histogram for each numeric columns
ins_df.hist(column = ["charges","bmi","age"])
plt.show()

# %%
# Box Plot for each numeric columns
ins_df.charges.plot.box()
plt.show()
